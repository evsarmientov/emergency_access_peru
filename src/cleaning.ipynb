# %%
# Cleaning

Este notebook limpia y estandariza los cuatro datasets crudos.
Para cada dataset:
- Se renombran columnas a snake_case
- Se eliminan duplicados
- Se manejan valores inválidos o nulos
- Se guarda el resultado limpio en `data/processed/`
